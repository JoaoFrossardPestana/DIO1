# %% [markdown]
# ## Exemplo de um Perceptron

# %% [markdown]
# Para este exemplo, vamos criar um dataset que simula a não linearidade da operação XOR. Para isto, criaremos quatro grupos distintos de dados.

# %%
# Criando o dataset XOR

import numpy as np                          # carrega a biblioteca numpy para operações matriciais

from sklearn.preprocessing import StandardScaler  # importa o método Standard Scaler para a normalização (escalamento) dos dados
from sklearn.utils import shuffle    # metodo shuffle vai embaralhar os pontos gerados

np.random.seed(1000)   # define a seed do random para que o experimento possa ser reproduzido

nb_samples = 1000              #serão criados 1000 pontos
nsb = int(nb_samples / 4)      #divididos em 4 grupos
X = np.zeros((nb_samples, 2))  #onde aqui definimos o tamanho do conjunto X (pontos) - 1000 pontos com 2 dimensões (coordenadas)
Y = np.zeros((nb_samples, ))   #e do Y (classes conjunto roxo = 1 ou conjunto amarelo = 0)

#vamos definir a pequena variação entre os pontos de cada conjunto
#coordenada 1, -1
X[0:nsb, :] = np.random.multivariate_normal([1.0, -1.0], np.diag([0.1, 0.1]), size=nsb)
Y[0:nsb] = 0.0 # classe 0

#coordenada 1, 1
X[nsb:(2 * nsb), :] = np.random.multivariate_normal([1.0, 1.0], np.diag([0.1, 0.1]), size=nsb)
Y[nsb:(2 * nsb)] = 1.0 #classe 1

#coordenada -1, 1
X[(2 * nsb):(3 * nsb), :] = np.random.multivariate_normal([-1.0, 1.0], np.diag([0.1, 0.1]), size=nsb)
Y[(2 * nsb):(3 * nsb)] = 0.0 #classe 0

#coordenada -1, -1
X[(3 * nsb):, :] = np.random.multivariate_normal([-1.0, -1.0], np.diag([0.1, 0.1]), size=nsb)
Y[(3 * nsb):] = 1.0 #classe 1

ss = StandardScaler()
X = ss.fit_transform(X) #normaliza os dados para a escala entre 0,1

X, Y = shuffle(X, Y, random_state=1000) # embaralha os dados

# %%
#Exibindo dataset XOR
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.show()

# %% [markdown]
# ### Vamos verificar a acurácia usando um perceptron?

# %%
import numpy as np # carrega o numpy

from multiprocessing import cpu_count  #cpu_count define quantos núcles tem o computador - para usar paralelismo durante a execução do algoritmo

from sklearn.linear_model import Perceptron  #importa o modelo perceptron  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
from sklearn.model_selection import cross_val_score #utiliza o método cross validation para indicar a acurácia média do modelo

pc = Perceptron(penalty='l2', alpha=0.1, max_iter=1000, n_jobs=cpu_count(), random_state=1000) # carrega o perceptron
print(np.mean(cross_val_score(pc, X, Y, cv=10))) # exibe o a acuracia média encontrada pelo modelo
# Out:
# 0.5039999999999999

# %% [markdown]
# ### Como o perceptron separa as regiões?

# %%
#Funções para plotar a superficie (regiões)
#para demonstrar separação pelo modelo criado
#######Não estuddo

import numpy as np
import matplotlib.pyplot as plt

def make_meshgrid(x, y, h=.02):
    #define a grade para as coordenadas do gráfico
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

def plot_contours(ax, clf, xx, yy, **params):
    #executa a classificação usando o modelo carregado em clf
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

def plot_model(clf):
    fig, ax = plt.subplots()
    # titulo do gráfico
    title = ('Superfície de Decisão')
    # configura as cooredenadas para plotar o gráfico
    X0, X1 = X[:, 0], X[:, 1]
    xx, yy = make_meshgrid(X0, X1)

    #chama a funcao pra definir os valores do modelo
    plot_contours(ax, clf, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=Y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_title(title)
    plt.show()

# %%
pc.fit(X, Y) # realiza o aprendizado do modelo carregado em pc
plot_model(pc) # as funções acima para executar a classificação e exibir a linha de separaçao dos resultados

# %% [markdown]
# ## MLP - Multilayer Perceptrons

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential() # carrega um modelo feed-forward

model.add(Dense(4, input_dim=2)) #cria uma camada densa com com 4 neuronios e 2 entradas
model.add(Activation('tanh'))   #usando função de ativação tangente hiperbólica

model.add(Dense(2))  #cria uma camada densa com com 2 neuronios (que recebe as saídas da camada anterior)
model.add(Activation('softmax'))   #usando função de ativação softmax para definir qual é a classe na saída

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']) # define a rede neural
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#vamos separar o conjunto de treinamento e de testes
#30% para testes, o restante para treinamento

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Y = to_categorical(Y, num_classes=2) # Converte numérico 0 e 1 para categorias


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1000) # separa o conjunto de teste com 30% dos dados sorteados aleatóriamente com seed = 1000
#outros 70% são definidos no conjunto de teste

# %%
#treinamento da rede neural
#usando 100 épocas

#método fit executa o treinamento
model.fit(X_train,  #para o conjunto de teste "train" onde x_train sao os atributos
          to_categorical(Y_train, num_classes=2),  #e Y_train sao as classes
          epochs=100,  #em 100 épocas
          batch_size=32, #de 32 em 32
          validation_data=(X_test, to_categorical(Y_test, num_classes=2))) # e demonstrando a acurácia de teste com o conjunto "X_test e Y_test"
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5086 - loss: 0.7619 - val_accuracy: 0.5700 - val_loss: 0.7233
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5386 - loss: 0.7407 - val_accuracy: 0.5867 - val_loss: 0.7092
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5557 - loss: 0.7231 - val_accuracy: 0.5933 - val_loss: 0.6978
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5886 - loss: 0.7077 - val_accuracy: 0.6000 - val_loss: 0.6880
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6086 - loss: 0.6949 - val_accuracy: 0.6200 - val_loss: 0.6800
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6286 - loss: 0.6836 - val_accuracy: 0.6433 - val_loss: 0.6726
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6729 - loss: 0.6734 - val_accuracy: 0.6900 - val_loss: 0.6650
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7043 - loss: 0.6638 - val_accuracy: 0.7400 - val_loss: 0.6587
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7257 - loss: 0.6552 - val_accuracy: 0.7500 - val_loss: 0.6517
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7286 - loss: 0.6462 - val_accuracy: 0.7433 - val_loss: 0.6445
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7214 - loss: 0.6379 - val_accuracy: 0.7333 - val_loss: 0.6380
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7186 - loss: 0.6296 - val_accuracy: 0.7267 - val_loss: 0.6304
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7314 - loss: 0.6209 - val_accuracy: 0.7200 - val_loss: 0.6230
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7586 - loss: 0.6123 - val_accuracy: 0.7500 - val_loss: 0.6148
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7871 - loss: 0.6034 - val_accuracy: 0.7833 - val_loss: 0.6061
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8157 - loss: 0.5939 - val_accuracy: 0.8133 - val_loss: 0.5964
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8386 - loss: 0.5843 - val_accuracy: 0.8400 - val_loss: 0.5864
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8443 - loss: 0.5742 - val_accuracy: 0.8500 - val_loss: 0.5762
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8529 - loss: 0.5638 - val_accuracy: 0.8667 - val_loss: 0.5662
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8829 - loss: 0.5531 - val_accuracy: 0.8933 - val_loss: 0.5548
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8957 - loss: 0.5421 - val_accuracy: 0.9067 - val_loss: 0.5439
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9086 - loss: 0.5306 - val_accuracy: 0.9200 - val_loss: 0.5323
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.5191 - val_accuracy: 0.9300 - val_loss: 0.5205
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9300 - loss: 0.5074 - val_accuracy: 0.9567 - val_loss: 0.5076
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9343 - loss: 0.4954 - val_accuracy: 0.9533 - val_loss: 0.4960
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9414 - loss: 0.4834 - val_accuracy: 0.9633 - val_loss: 0.4836
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9443 - loss: 0.4711 - val_accuracy: 0.9767 - val_loss: 0.4707
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9543 - loss: 0.4591 - val_accuracy: 0.9767 - val_loss: 0.4581
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9929 - loss: 0.1080 - val_accuracy: 0.9967 - val_loss: 0.1063
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.1046 - val_accuracy: 0.9967 - val_loss: 0.1030
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9929 - loss: 0.1014 - val_accuracy: 0.9967 - val_loss: 0.0998
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0983 - val_accuracy: 0.9967 - val_loss: 0.0969
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0953 - val_accuracy: 0.9967 - val_loss: 0.0939
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9914 - loss: 0.0925 - val_accuracy: 0.9967 - val_loss: 0.0910
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9914 - loss: 0.0898 - val_accuracy: 0.9967 - val_loss: 0.0883
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.0872 - val_accuracy: 0.9967 - val_loss: 0.0858
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9914 - loss: 0.0847 - val_accuracy: 0.9967 - val_loss: 0.0834
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.0823 - val_accuracy: 0.9967 - val_loss: 0.0811
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9914 - loss: 0.0801 - val_accuracy: 0.9967 - val_loss: 0.0787
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.0779 - val_accuracy: 0.9967 - val_loss: 0.0768
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0758 - val_accuracy: 0.9967 - val_loss: 0.0747
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9929 - loss: 0.0738 - val_accuracy: 0.9967 - val_loss: 0.0727
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0718 - val_accuracy: 0.9967 - val_loss: 0.0708
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0700 - val_accuracy: 0.9967 - val_loss: 0.0690
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0683 - val_accuracy: 0.9967 - val_loss: 0.0673
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0666 - val_accuracy: 0.9967 - val_loss: 0.0657
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0649 - val_accuracy: 0.9967 - val_loss: 0.0641
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0634 - val_accuracy: 0.9967 - val_loss: 0.0624
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0619 - val_accuracy: 0.9967 - val_loss: 0.0610
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0604 - val_accuracy: 0.9967 - val_loss: 0.0596
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0591 - val_accuracy: 0.9967 - val_loss: 0.0583
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0577 - val_accuracy: 0.9967 - val_loss: 0.0569
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0564 - val_accuracy: 0.9967 - val_loss: 0.0557

# %%
#verificação(predição) usando a base de teste
#qual seria a resposta da rede treinada se ela classificar os pontos que estao no conjunto de testes?

Y_eval_mlp = np.argmax(model.predict(X_test), axis=1) #retorna as classes definidas pelo modelo
#display(Y_eval_mlp)
acuracia = np.mean(Y_eval_mlp == Y_test) * 100
print(f"Acurácia: {acuracia:.2f}%")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Acurácia: 99.67%

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %%
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_teste
plt.show() #exibe gráfico

# %%
plt.scatter(X_test[:, 0], X_test[:, 1], c=abs(Y_test-Y_eval_mlp)) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_teste plt.show() #exibe gráfico
plt.show() #exibe gráfico

# %% [markdown]
# ### Superficie usando o modelo atual com tanh

# %%
#para verificarmos os limites entre os conjuntos de classificação
#vamos criar um conjunto com muitos pontos gerados aleatóriamente
#e usar o modelo para definir qual seria sua classe

import numpy as np

Xm = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada X
Ym = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada Y
Xmg, Ymg = np.meshgrid(Xm, Ym)  #retorna as coordenadas da grade 2-D com base nas coordenadas contidas nos vetores x e y
#display(Xmg)
#display(Ymg)
X_eval = np.vstack([Xmg.ravel(), Ymg.ravel()]).T #cria o conjunto de entradas para as coordenadas geradas

Y_eval_mlp = np.argmax(model.predict(X_eval), axis=1) # usa o modelo carregado em model para realizar a classificação
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_eval[:, 0], X_eval[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %% [markdown]
# ### E se criarmos um modelo usando função de ativação Relu?

# %%
#para isto, vamos reproduzir a mesma rede neural anterior
#mas mudando a função de ativação

model = Sequential() # carrega um modelo feed-forward

model.add(Dense(4, input_dim=2)) #cria uma camada densa com com 4 neuronios e 2 entradas
model.add(Activation('relu'))   #usando função de ativação relu

model.add(Dense(2))  #cria uma camada densa com com 2 neuronios (que recebe as saídas da camada anterior)
model.add(Activation('softmax'))   #usando função de ativação softmax para definir qual é a classe na saída

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']) # define a rede neural

# %%
#vamos separar o conjunto de treinamento e de testes
#30% para testes, o restante para treinamento

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1000) # separa o conjunto de teste com 30% dos dados sorteados aleatóriamente com seed = 1000
#outros 70% são definidos no conjunto de teste

#treinamento da rede neural
#usando 100 épocas

#método fit executa o treinamento
model.fit(X_train,  #para o conjunto de teste "train" onde x_train sao os atributos
          to_categorical(Y_train, num_classes=2),  #e y_train sao as classes
          epochs=100,  #em 100 épocas
          batch_size=32, #de 32 em 32
          validation_data=(X_test, to_categorical(Y_test, num_classes=2))) # e demonstrando a acurácia de teste com o conjunto "X_test e Y_test"
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5886 - loss: 0.7070 - val_accuracy: 0.5667 - val_loss: 0.7526
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6357 - loss: 0.6817 - val_accuracy: 0.6033 - val_loss: 0.7209
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6643 - loss: 0.6583 - val_accuracy: 0.6300 - val_loss: 0.6934
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6871 - loss: 0.6369 - val_accuracy: 0.6500 - val_loss: 0.6668
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7057 - loss: 0.6161 - val_accuracy: 0.6600 - val_loss: 0.6426
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7129 - loss: 0.5962 - val_accuracy: 0.6733 - val_loss: 0.6192
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7200 - loss: 0.5769 - val_accuracy: 0.6833 - val_loss: 0.5955
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7457 - loss: 0.5578 - val_accuracy: 0.7100 - val_loss: 0.5723
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7757 - loss: 0.5387 - val_accuracy: 0.7633 - val_loss: 0.5504
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8457 - loss: 0.5201 - val_accuracy: 0.8533 - val_loss: 0.5280
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9014 - loss: 0.5014 - val_accuracy: 0.9033 - val_loss: 0.5060
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9271 - loss: 0.4830 - val_accuracy: 0.9400 - val_loss: 0.4844
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9386 - loss: 0.4646 - val_accuracy: 0.9567 - val_loss: 0.4643
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9471 - loss: 0.4470 - val_accuracy: 0.9700 - val_loss: 0.4431
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.4294 - val_accuracy: 0.9767 - val_loss: 0.4244
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9557 - loss: 0.4127 - val_accuracy: 0.9800 - val_loss: 0.4059
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9614 - loss: 0.3967 - val_accuracy: 0.9833 - val_loss: 0.3883
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9600 - loss: 0.3815 - val_accuracy: 0.9833 - val_loss: 0.3718
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.3672 - val_accuracy: 0.9833 - val_loss: 0.3558
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.3532 - val_accuracy: 0.9833 - val_loss: 0.3421
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.3403 - val_accuracy: 0.9833 - val_loss: 0.3284
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.3279 - val_accuracy: 0.9833 - val_loss: 0.3153
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9657 - loss: 0.3161 - val_accuracy: 0.9833 - val_loss: 0.3029
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9657 - loss: 0.3049 - val_accuracy: 0.9833 - val_loss: 0.2912
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.2943 - val_accuracy: 0.9833 - val_loss: 0.2800
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9657 - loss: 0.2843 - val_accuracy: 0.9833 - val_loss: 0.2696
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0.2748 - val_accuracy: 0.9833 - val_loss: 0.2598
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0.2657 - val_accuracy: 0.9833 - val_loss: 0.2503
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0.2572 - val_accuracy: 0.9833 - val_loss: 0.2413
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9914 - loss: 0.0913 - val_accuracy: 1.0000 - val_loss: 0.0750
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0898 - val_accuracy: 1.0000 - val_loss: 0.0737
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0883 - val_accuracy: 1.0000 - val_loss: 0.0720
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9914 - loss: 0.0869 - val_accuracy: 1.0000 - val_loss: 0.0706
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0854 - val_accuracy: 1.0000 - val_loss: 0.0695
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0840 - val_accuracy: 1.0000 - val_loss: 0.0682
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0827 - val_accuracy: 1.0000 - val_loss: 0.0670
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0814 - val_accuracy: 1.0000 - val_loss: 0.0656
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0802 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0789 - val_accuracy: 1.0000 - val_loss: 0.0635
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0777 - val_accuracy: 1.0000 - val_loss: 0.0623
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0765 - val_accuracy: 1.0000 - val_loss: 0.0612
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0754 - val_accuracy: 1.0000 - val_loss: 0.0600
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0742 - val_accuracy: 1.0000 - val_loss: 0.0592
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0731 - val_accuracy: 1.0000 - val_loss: 0.0582
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0720 - val_accuracy: 1.0000 - val_loss: 0.0572
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0710 - val_accuracy: 1.0000 - val_loss: 0.0562
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0700 - val_accuracy: 0.9967 - val_loss: 0.0555
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0690 - val_accuracy: 0.9967 - val_loss: 0.0545
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0680 - val_accuracy: 1.0000 - val_loss: 0.0534
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0671 - val_accuracy: 0.9967 - val_loss: 0.0526
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0662 - val_accuracy: 0.9967 - val_loss: 0.0518
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0652 - val_accuracy: 1.0000 - val_loss: 0.0509
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0643 - val_accuracy: 1.0000 - val_loss: 0.0501
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0635 - val_accuracy: 0.9967 - val_loss: 0.0495
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0626 - val_accuracy: 1.0000 - val_loss: 0.0485
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0618 - val_accuracy: 0.9967 - val_loss: 0.0478

# %%
#verificação(predição) usando a base de teste
#qual seria a resposta da rede treinada se ela classificar os pontos que estao no conjunto de testes?

Y_eval_mlp = np.argmax(model.predict(X_test), axis=1) #retorna as classes definidas pelo modelo
acuracia = np.mean(Y_eval_mlp == Y_test) * 100
print(f"Acurácia: {acuracia:.2f}%")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Acurácia: 99.67%

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico

# %%
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_teste
plt.show() #exibe gráfico

# %%
Y_eval_mlp_for_plot = np.argmax(model.predict(X_test), axis=1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=abs(Y_test-Y_eval_mlp_for_plot)) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_teste plt.show() #exibe gráfico
plt.show() #exibe gráfico
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
#para verificarmos os limites entre os conjuntos de classificação
#vamos criar um conjunto com muitos pontos gerados aleatóriamente
#e usar o modelo para definir qual seria sua classe

import numpy as np

Xm = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada X
Ym = np.linspace(-2.0, 2.0, 1000) # cria 1000 pontos para a coordenada Y
Xmg, Ymg = np.meshgrid(Xm, Ym)  #retorna as coordenadas da grade 2-D com base nas coordenadas contidas nos vetores x e y
X_eval = np.vstack([Xmg.ravel(), Ymg.ravel()]).T #cria o conjunto de entradas para as coordenadas geradas

Y_eval_mlp = np.argmax(model.predict(X_eval), axis=1) # usa o modelo carregado em model para realizar a classificação
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step

# %%
#plotando os resultados
import matplotlib.pyplot as plt
plt.scatter(X_eval[:, 0], X_eval[:, 1], c=Y_eval_mlp) # exibe pontos para coordenadas em X_Test definindo as cores a partir dos dados em Y_eval_mlp
plt.show() #exibe gráfico
